# %%
import pandas as pd
import numpy as np
import json

# %%
file = open('MitreData.json')

obj_list = []
dict = {}

for line in file:
    obj_list.append(eval(line))

new_list = []
for item in obj_list:
    if(item['id']=='T1197'):
        print(item.keys())
        # print(item.values())
    if(len(item['tactics'])>1):
        for tactic in item['tactics']:
            dict = item
            dict['tactics'] = tactic
            new_list.append(dict)
    else:
        dict = item
        dict['tactics'] = item['tactics'][0]
        new_list.append(dict)

df = pd.DataFrame(new_list)
df.head()
# Out:
# dict_keys(['techniquename', 'detection', 'description', 'mitigations', 'procedureexamples', 'id', 'subtechniques', 'tactics', 'platforms', 'permissionsrequired', 'defensebypassed', 'contributors', 'version', 'created', 'lastmodified'])
#             techniquename                                          detection  \
# 0            Web Services  Once adversaries leverage the web service as i...
# 1  Virtual Private Server  Once adversaries have provisioned a VPS (ex: f...
# 2              DNS Server  Much of this activity will take place outside ...
# 3  Acquire Infrastructure  Consider use of services that may aid in track...
# 4                  Server  Once adversaries have provisioned a server (ex...
#
#                                          description  \
# 0  Adversaries may register for web services that...
# 1  Adversaries may rent Virtual Private Servers (...
# 2  Adversaries may set up their own Domain Name S...
# 3  Adversaries may buy, lease, or rent infrastruc...
# 4  Adversaries may buy, lease, or rent physical s...
#
#                                          mitigations  \
# 0  {'M1056': ' Pre-compromise  : This technique c...
# 1  {'M1056': ' Pre-compromise  : This technique c...
# 2  {'M1056': ' Pre-compromise  : This technique c...
# 3  {'M1056': ' Pre-compromise  : This technique c...
# 4  {'M1056': ' Pre-compromise  : This technique c...
#
#                                    procedureexamples         id  \
# 0  {'G0025': ' APT17  : APT17 has created profile...  T1583.006
# 1  {'G0125': ' HAFNIUM  : HAFNIUM has operated fr...  T1583.003
# 2                                                NaN  T1583.002
# 3                                                NaN      T1583
# 4  {'G0093': ' GALLIUM  : GALLIUM has used Taiwan...  T1583.004
#
#   subtechniqueof               tactics platforms version  ...  \
# 0          T1583  Resource Development     [PRE]     1.1  ...
# 1          T1583  Resource Development     [PRE]     1.1  ...
# 2          T1583  Resource Development     [PRE]     1.0  ...
# 3            NaN  Resource Development     [PRE]     1.1  ...
# 4          T1583  Resource Development     [PRE]     1.1  ...
#
#                                        subtechniques capecid contributors  \
# 0                                                NaN     NaN          NaN
# 1                                                NaN     NaN          NaN
# 2                                                NaN     NaN          NaN
# 3  [T1583.001, T1583.002, T1583.003, T1583.004, T...     NaN          NaN
# 4                                                NaN     NaN          NaN
#
#   impacttype permissionsrequired requiresnetwork systemrequirements  \
# 0        NaN                 NaN             NaN                NaN
# 1        NaN                 NaN             NaN                NaN
# 2        NaN                 NaN             NaN                NaN
# 3        NaN                 NaN             NaN                NaN
# 4        NaN                 NaN             NaN                NaN
#
#   defensebypassed effectivepermissions supportsremote
# 0             NaN                  NaN            NaN
# 1             NaN                  NaN            NaN
# 2             NaN                  NaN            NaN
# 3             NaN                  NaN            NaN
# 4             NaN                  NaN            NaN
#
# [5 rows x 22 columns]

# %%
fileD = open('DataSources.json')

objD_list = []
for line in fileD:
    objD_list.append(eval(line))
    
df_DS = pd.DataFrame(objD_list)
df_DS.head()
# Out:
#                  name                                        description  \
# 0  Malware Repository  Information obtained (via shared or submitted ...
# 1          Named Pipe  Mechanisms that allow inter-process communicat...
# 2       Internet Scan  Information obtained (commonly via active netw...
# 3       Network Share  A storage resource (typically a folder or driv...
# 4    Active Directory  A database and set of services that allows adm...
#
#        id platform collectionlayer version          created      lastmodified  \
# 0  DS0004      PRE           OSINT   : 1.0  20 October 2021   20 October 2021
# 1  DS0023      NaN            Host   : 1.0  20 October 2021  10 November 2021
# 2  DS0035      PRE           OSINT   : 1.0  20 October 2021   20 October 2021
# 3  DS0033      NaN            Host   : 1.0  20 October 2021  10 November 2021
# 4  DS0026      NaN             NaN   : 1.0  20 October 2021  10 November 2021
#
#                                       datacomponents              platforms  \
# 0  [{'Malware Content': {'description': 'Code, st...                    NaN
# 1  [{'Named Pipe Metadata': {'description': 'Cont...  Linux, Windows, macOS
# 2  [{'Response Content': {'description': 'Logged ...                    NaN
# 3  [{'Network Share Access': {'description': 'Ope...  Linux, Windows, macOS
# 4  [{'Active Directory Credential Request': {'des...      Azure AD, Windows
#
#                                   contributors           collectionlayers
# 0                                          NaN                        NaN
# 1  : Center for Threat-Informed Defense (CTID)                        NaN
# 2                                          NaN                        NaN
# 3  : Center for Threat-Informed Defense (CTID)                        NaN
# 4  : Center for Threat-Informed Defense (CTID)  Cloud Control Plane, Host

# %%
df.drop(df.iloc[:, 8:22], inplace = True, axis = 1)
df.drop(['subtechniqueof'], inplace = True, axis = 1)
df.head()
# Out:
#             techniquename                                          detection  \
# 0            Web Services  Once adversaries leverage the web service as i...
# 1  Virtual Private Server  Once adversaries have provisioned a VPS (ex: f...
# 2              DNS Server  Much of this activity will take place outside ...
# 3  Acquire Infrastructure  Consider use of services that may aid in track...
# 4                  Server  Once adversaries have provisioned a server (ex...
#
#                                          description  \
# 0  Adversaries may register for web services that...
# 1  Adversaries may rent Virtual Private Servers (...
# 2  Adversaries may set up their own Domain Name S...
# 3  Adversaries may buy, lease, or rent infrastruc...
# 4  Adversaries may buy, lease, or rent physical s...
#
#                                          mitigations  \
# 0  {'M1056': ' Pre-compromise  : This technique c...
# 1  {'M1056': ' Pre-compromise  : This technique c...
# 2  {'M1056': ' Pre-compromise  : This technique c...
# 3  {'M1056': ' Pre-compromise  : This technique c...
# 4  {'M1056': ' Pre-compromise  : This technique c...
#
#                                    procedureexamples         id  \
# 0  {'G0025': ' APT17  : APT17 has created profile...  T1583.006
# 1  {'G0125': ' HAFNIUM  : HAFNIUM has operated fr...  T1583.003
# 2                                                NaN  T1583.002
# 3                                                NaN      T1583
# 4  {'G0093': ' GALLIUM  : GALLIUM has used Taiwan...  T1583.004
#
#                 tactics
# 0  Resource Development
# 1  Resource Development
# 2  Resource Development
# 3  Resource Development
# 4  Resource Development

# %%
df['techniquename'].value_counts()
tactics = df['techniquename'].unique()
dict_target = {}
i = 0
for x in tactics:
    dict_target[x] = i
    i = i + 1
print(dict_target)

df['num_target']=df['techniquename'].map(dict_target)
df.head()
# Out:
# {'Web Services': 0, 'Virtual Private Server': 1, 'DNS Server': 2, 'Acquire Infrastructure': 3, 'Server': 4, 'Domains': 5, 'Botnet': 6, 'Active Scanning': 7, 'Search Victim-Owned Websites': 8, 'Search Engines': 9, 'Social Media': 10, 'Search Open Websites/Domains': 11, 'DNS/Passive DNS': 12, 'CDNs': 13, 'Digital Certificates': 14, 'WHOIS': 15, 'Scan Databases': 16, 'Search Closed Sources': 17, 'Spearphishing Link': 18, 'Spearphishing Service': 19, 'Search Open Technical Databases': 20, 'Purchase Technical Data': 21, 'Threat Intel Vendors': 22, 'Business Relationships': 23, 'IP Addresses': 24, 'Spearphishing Attachment': 25, 'Network Security Appliances': 26, 'Phishing for Information': 27, 'Identify Roles': 28, 'Identify Business Tempo': 29, 'Determine Physical Locations': 30, 'Gather Victim Org Information': 31, 'Network Denial of Service': 32, 'Inhibit System Recovery': 33, 'Direct Network Flood': 34, 'Reflection Amplification': 35, 'Resource Hijacking': 36, 'System Shutdown/Reboot': 37, 'Service Stop': 38, 'Disk Content Wipe': 39, 'Endpoint Denial of Service': 40, 'OS Exhaustion Flood': 41, 'Service Exhaustion Flood': 42, 'Application Exhaustion Flood': 43, 'Application or System Exploitation': 44, 'Firmware Corruption': 45, 'Disk Wipe': 46, 'Stored Data Manipulation': 47, 'Transmitted Data Manipulation': 48, 'Runtime Data Manipulation': 49, 'Defacement': 50, 'Internal Defacement': 51, 'Disk Structure Wipe': 52, 'External Defacement': 53, 'Transfer Data to Cloud Account': 54, 'Data Manipulation': 55, 'Data Encrypted for Impact': 56, 'Exfiltration Over Web Service': 57, 'Exfiltration to Cloud Storage': 58, 'Exfiltration to Code Repository': 59, 'Scheduled Transfer': 60, 'Account Access Removal': 61, 'Exfiltration over USB': 62, 'Data Destruction': 63, 'Exfiltration Over Unencrypted/Obfuscated Non-C2 Protocol': 64, 'Exfiltration Over Symmetric Encrypted Non-C2 Protocol': 65, 'Exfiltration Over C2 Channel': 66, 'Exfiltration Over Bluetooth': 67, 'Exfiltration Over Physical Medium': 68, 'Exfiltration Over Asymmetric Encrypted Non-C2 Protocol': 69, 'Automated Exfiltration': 70, 'Exfiltration Over Alternative Protocol': 71, 'One-Way Communication': 72, 'Traffic Duplication': 73, 'Data Transfer Size Limits': 74, 'Exfiltration Over Other Network Medium': 75, 'Bidirectional Communication': 76, 'Dead Drop Resolver': 77, 'Internal Proxy': 78, 'Web Service': 79, 'External Proxy': 80, 'Multi-hop Proxy': 81, 'Domain Fronting': 82, 'Remote Access Software': 83, 'Proxy': 84, 'Protocol Tunneling': 85, 'Fallback Channels': 86, 'Asymmetric Cryptography': 87, 'Multi-Stage Channels': 88, 'Non-Application Layer Protocol': 89, 'Non-Standard Port': 90, 'Ingress Tool Transfer': 91, 'Encrypted Channel': 92, 'Symmetric Cryptography': 93, 'Fast Flux DNS': 94, 'DNS Calculation': 95, 'Dynamic Resolution': 96, 'Junk Data': 97, 'Steganography': 98, 'Protocol Impersonation': 99, 'Data Obfuscation': 100, 'Domain Generation Algorithms': 101, 'Data Encoding': 102, 'DNS': 103, 'Communication Through Removable Media': 104, 'Non-Standard Encoding': 105, 'File Transfer Protocols': 106, 'Mail Protocols': 107, 'Video Capture': 108, 'Standard Encoding': 109, 'Email Forwarding Rule': 110, 'Application Layer Protocol': 111, 'Web Protocols': 112, 'Local Email Collection': 113, 'Remote Email Collection': 114, 'Data Staged': 115, 'Screen Capture': 116, 'Data from Local System': 117, 'Data from Removable Media': 118, 'Local Data Staging': 119, 'Data from Network Shared Drive': 120, 'Remote Data Staging': 121, 'Email Collection': 122, 'Code Repositories': 123, 'Confluence': 124, 'Sharepoint': 125, 'Data from Information Repositories': 126, 'Network Device Configuration Dump': 127, 'Clipboard Data': 128, 'Automated Collection': 129, 'Data from Cloud Storage Object': 130, 'Data from Configuration Repository': 131, 'SNMP (MIB Dump)': 132, 'Browser Session Hijacking': 133, 'Archive Collected Data': 134, 'Archive via Utility': 135, 'Archive via Library': 136, 'Archive via Custom ...
#             techniquename                                          detection  \
# 0            Web Services  Once adversaries leverage the web service as i...
# 1  Virtual Private Server  Once adversaries have provisioned a VPS (ex: f...
# 2              DNS Server  Much of this activity will take place outside ...
# 3  Acquire Infrastructure  Consider use of services that may aid in track...
# 4                  Server  Once adversaries have provisioned a server (ex...
#
#                                          description  \
# 0  Adversaries may register for web services that...
# 1  Adversaries may rent Virtual Private Servers (...
# 2  Adversaries may set up their own Domain Name S...
# 3  Adversaries may buy, lease, or rent infrastruc...
# 4  Adversaries may buy, lease, or rent physical s...
#
#                                          mitigations  \
# 0  {'M1056': ' Pre-compromise  : This technique c...
# 1  {'M1056': ' Pre-compromise  : This technique c...
# 2  {'M1056': ' Pre-compromise  : This technique c...
# 3  {'M1056': ' Pre-compromise  : This technique c...
# 4  {'M1056': ' Pre-compromise  : This technique c...
#
#                                    procedureexamples         id  \
# 0  {'G0025': ' APT17  : APT17 has created profile...  T1583.006
# 1  {'G0125': ' HAFNIUM  : HAFNIUM has operated fr...  T1583.003
# 2                                                NaN  T1583.002
# 3                                                NaN      T1583
# 4  {'G0093': ' GALLIUM  : GALLIUM has used Taiwan...  T1583.004
#
#                 tactics  num_target
# 0  Resource Development           0
# 1  Resource Development           1
# 2  Resource Development           2
# 3  Resource Development           3
# 4  Resource Development           4

# %%
df['combined'] = df[['detection', 'description', 'mitigations','tactics']].apply(lambda x: ",".join(x.astype(str)), axis=1)
print(df['combined'])
# Out:
# 0      Once adversaries leverage the web service as i...
# 1      Once adversaries have provisioned a VPS (ex: f...
# 2      Much of this activity will take place outside ...
# 3      Consider use of services that may aid in track...
# 4      Once adversaries have provisioned a server (ex...
#                              ...
# 726    Internet scanners may be used to look for patt...
# 727    Internet scanners may be used to look for patt...
# 728    Monitor for suspicious network traffic that co...
# 729    Much of this activity may have a very high occ...
# 730    Monitor for suspicious network traffic that co...
# Name: combined, Length: 731, dtype: object

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df.combined, df['num_target'], test_size=0.2, random_state=50)
#x_train, x_test, y_train, y_test = train_test_split(df.loc[:, ["detection", "description", "mitigations", "procedureexamples"]], df['num_target'], random_state=50)
print(x_train)
# Out:
# 503    Monitor emond rules creation by checking for f...
# 157    System and network discovery techniques normal...
# 356    Exploitation for defense evasion may happen sh...
# 100    Analyze network data for uncommon data flows (...
# 608    Detection methods will vary depending on the t...
#                              ...
# 132    Identify network traffic sent or received by u...
# 289    Use process monitoring to monitor the executio...
# 109    Analyze network data for uncommon data flows (...
# 480    Look for changes to binaries and service execu...
# 688    If infrastructure or patterns in malware, tool...
# Name: combined, Length: 584, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer

vect = CountVectorizer(ngram_range=(2,2))
#converting traning features into numeric vector
X_train = vect.fit_transform(x_train)
#converting training labels into numeric vector
X_test = vect.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(n_estimators = 100) 
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(y_pred)
# Out:
# [229 204 259 405 251 349 504 435 364 204 483 368  45 355 395  21 244 222
#  525 103 391 496  55 497 427 105 475 238  14 428 540 422  79 193 473 498
#    2 260  14 391 123 405 407 218 384  25 348 396 527 137 188 407 365 128
#   84 474 484 541 512 403 543  20   6 402 353 501 370 150 307 220  98 222
#  204 199 404 166 348 222  31 217 247 375 220 543 279 424 372 131 543 425
#  499  28 449 493  91 494 117 326 435 150  70 521 345 367 250 222  61 263
#  361 504 391 107 465 399 348 416 267 122 204 455 207 476  62 252 393 540
#  241 498 470 450  98  31 263 355 440 321 113 365 181 391   6 227  32  19
#    6 409 238]

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_pred,y_test)
# Out:
# 0.4013605442176871

# %%
def predict_tactic(num):
    print(dict_target)
    for key, value in dict_target.items():
        if num == value:
            return key

# %%
desc = ["new System Process Creation detected = Create or Modify System Process"]
desc2 = ["Adversaries may execute active reconnaissance scans to gather information that can be used during targeting."]
test = vect.transform(desc2)
pred= clf.predict(test)
print(pred)
r = predict_tactic(pred)
print (r)
# Out:
# [6]
# {'Web Services': 0, 'Virtual Private Server': 1, 'DNS Server': 2, 'Acquire Infrastructure': 3, 'Server': 4, 'Domains': 5, 'Botnet': 6, 'Active Scanning': 7, 'Search Victim-Owned Websites': 8, 'Search Engines': 9, 'Social Media': 10, 'Search Open Websites/Domains': 11, 'DNS/Passive DNS': 12, 'CDNs': 13, 'Digital Certificates': 14, 'WHOIS': 15, 'Scan Databases': 16, 'Search Closed Sources': 17, 'Spearphishing Link': 18, 'Spearphishing Service': 19, 'Search Open Technical Databases': 20, 'Purchase Technical Data': 21, 'Threat Intel Vendors': 22, 'Business Relationships': 23, 'IP Addresses': 24, 'Spearphishing Attachment': 25, 'Network Security Appliances': 26, 'Phishing for Information': 27, 'Identify Roles': 28, 'Identify Business Tempo': 29, 'Determine Physical Locations': 30, 'Gather Victim Org Information': 31, 'Network Denial of Service': 32, 'Inhibit System Recovery': 33, 'Direct Network Flood': 34, 'Reflection Amplification': 35, 'Resource Hijacking': 36, 'System Shutdown/Reboot': 37, 'Service Stop': 38, 'Disk Content Wipe': 39, 'Endpoint Denial of Service': 40, 'OS Exhaustion Flood': 41, 'Service Exhaustion Flood': 42, 'Application Exhaustion Flood': 43, 'Application or System Exploitation': 44, 'Firmware Corruption': 45, 'Disk Wipe': 46, 'Stored Data Manipulation': 47, 'Transmitted Data Manipulation': 48, 'Runtime Data Manipulation': 49, 'Defacement': 50, 'Internal Defacement': 51, 'Disk Structure Wipe': 52, 'External Defacement': 53, 'Transfer Data to Cloud Account': 54, 'Data Manipulation': 55, 'Data Encrypted for Impact': 56, 'Exfiltration Over Web Service': 57, 'Exfiltration to Cloud Storage': 58, 'Exfiltration to Code Repository': 59, 'Scheduled Transfer': 60, 'Account Access Removal': 61, 'Exfiltration over USB': 62, 'Data Destruction': 63, 'Exfiltration Over Unencrypted/Obfuscated Non-C2 Protocol': 64, 'Exfiltration Over Symmetric Encrypted Non-C2 Protocol': 65, 'Exfiltration Over C2 Channel': 66, 'Exfiltration Over Bluetooth': 67, 'Exfiltration Over Physical Medium': 68, 'Exfiltration Over Asymmetric Encrypted Non-C2 Protocol': 69, 'Automated Exfiltration': 70, 'Exfiltration Over Alternative Protocol': 71, 'One-Way Communication': 72, 'Traffic Duplication': 73, 'Data Transfer Size Limits': 74, 'Exfiltration Over Other Network Medium': 75, 'Bidirectional Communication': 76, 'Dead Drop Resolver': 77, 'Internal Proxy': 78, 'Web Service': 79, 'External Proxy': 80, 'Multi-hop Proxy': 81, 'Domain Fronting': 82, 'Remote Access Software': 83, 'Proxy': 84, 'Protocol Tunneling': 85, 'Fallback Channels': 86, 'Asymmetric Cryptography': 87, 'Multi-Stage Channels': 88, 'Non-Application Layer Protocol': 89, 'Non-Standard Port': 90, 'Ingress Tool Transfer': 91, 'Encrypted Channel': 92, 'Symmetric Cryptography': 93, 'Fast Flux DNS': 94, 'DNS Calculation': 95, 'Dynamic Resolution': 96, 'Junk Data': 97, 'Steganography': 98, 'Protocol Impersonation': 99, 'Data Obfuscation': 100, 'Domain Generation Algorithms': 101, 'Data Encoding': 102, 'DNS': 103, 'Communication Through Removable Media': 104, 'Non-Standard Encoding': 105, 'File Transfer Protocols': 106, 'Mail Protocols': 107, 'Video Capture': 108, 'Standard Encoding': 109, 'Email Forwarding Rule': 110, 'Application Layer Protocol': 111, 'Web Protocols': 112, 'Local Email Collection': 113, 'Remote Email Collection': 114, 'Data Staged': 115, 'Screen Capture': 116, 'Data from Local System': 117, 'Data from Removable Media': 118, 'Local Data Staging': 119, 'Data from Network Shared Drive': 120, 'Remote Data Staging': 121, 'Email Collection': 122, 'Code Repositories': 123, 'Confluence': 124, 'Sharepoint': 125, 'Data from Information Repositories': 126, 'Network Device Configuration Dump': 127, 'Clipboard Data': 128, 'Automated Collection': 129, 'Data from Cloud Storage Object': 130, 'Data from Configuration Repository': 131, 'SNMP (MIB Dump)': 132, 'Browser Session Hijacking': 133, 'Archive Collected Data': 134, 'Archive via Utility': 135, 'Archive via Library': 136, 'Archive via Custom ...
# Botnet
